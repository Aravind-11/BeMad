# %%
import sys
sys.path.append( r'..\tesseract')

# %%
from sklearn.svm import SVC

import tesseract.evaluation as evaluation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\ATHARVA\Documents\Atharva\Malware Detection IP\Tesseract\ml_release\examples\test.ipynb Cell 2 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Documents/Atharva/Malware%20Detection%20IP/Tesseract/ml_release/examples/test.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.svm import SVC
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ATHARVA/Documents/Atharva/Malware%20Detection%20IP/Tesseract/ml_release/examples/test.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import tesseract.evaluation as evaluation
#
# ModuleNotFoundError: No module named 'tesseract'

# %%
# Generate dummy predictors, labels and timestamps from Gaussians
X, y, t = mock.generate_binary_test_data(10000, '2022', '2024')

# Partition dataset
splits = temporal.time_aware_train_test_split(
    X, y, t, train_size=12, test_size=1, granularity='month')

X_train, X_tests, y_train, y_tests, t_train, t_tests = splits

# Perform a timeline evaluation
clf = SVC(kernel='linear', probability=True)
clf.fit(X_train, y_train)

y_preds = evaluation.predict(clf, X_tests, nproc=4)
results = metrics.calculate_metrics(y_tests, y_preds, periods=-1)

# View results
metrics.print_metrics(results)

# View AUT(F1, 24 months) as a measure of robustness over time
print(metrics.aut(results, 'f1'))
